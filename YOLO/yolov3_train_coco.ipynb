# %% [markdown]
# ### Ultralytics Yolo v3 설치

# %%
import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.0.1 (NVIDIA GeForce RTX 3060)

# %%
# %cd ../yolov3
# !python train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights yolov3.pt --nosave
# Out:
# c:\Users\LegendKi\Documents\LegendKi_py\Deeplearning_CV\yolov3
# train: weights=yolov3.pt, cfg=, data=coco128.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# From https://github.com/ultralytics/yolov5
#  * [new branch]        add/weights_dir      -> ultralytics/add/weights_dir
#  * [new branch]        benchmarks           -> ultralytics/benchmarks
#  * [new branch]        dependabot/pip/tensorflow-lte-2.15.0.post1 -> ultralytics/dependabot/pip/tensorflow-lte-2.15.0.post1
# ...

# %% [markdown]
# ### wandb(weight and bias) 모듈을 설치
# * 먼저 Weight and Bias 웹사이트에 계정 생성 및 연계 후 train 작업이 필요할 수도 있음.

# %%
# !pip install wandb
# Out:
# ...
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------- -------------------------------- 0.4/2.2 MB 8.5 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.2 MB 10.6 MB/s eta 0:00:01
#    ------------------------------- -------- 1.7/2.2 MB 13.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 12.6 MB/s eta 0:00:00
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# ...
#    ---------------------------------------- 0.0/258.5 kB ? eta -:--:--
#    --------------------------------------- 258.5/258.5 kB 15.5 MB/s eta 0:00:00
# ...

# %%
# %cd ../yolov3
# !python train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights yolov3.pt --nosave --cache
# Out:
# c:\Users\LegendKi\Documents\LegendKi_py\Deeplearning_CV\yolov3
# wandb: WARNING  wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# train: weights=yolov3.pt, cfg=, data=coco128.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github:  YOLOv3 is out of date by 2768 commits. Use 'git pull ultralytics master' or 'git clone https://github.com/ultralytics/yolov5' to update.
# ...

# %% [markdown]
# ### Dataset Config와 Weight 파일의 상대 경로, 절대 경로
# * train.py의 data option값으로 Dataset config yaml 파일을 지정할 수 있으며, 파일명만 입력할 경우는 yolov3/data 디렉토리 아래에서 해당 파일을 찾음. 절대 경로로 입력할 경우 해당 경로에서 찾음.
# * weights option의 경우 파일명만 입력할 경우 yolov3 디렉토리에서 해당 파일을 찾음. 해당 파일이 없을 경우 자동으로 해당 파일을 https://github.com/ultralytics/yolov3/releases 에서 Download 함. 절대 경로를 입력한 경우 해당 경로에서 파일을 찾되 파일이 없으면 해당 경로로 자동 Download함.
# * weights 파일은 yolov3.pt, yolov3-tiny.pt, yolov3-spp.pt

# %%
# %cd ../yolov3
# !python train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights yolov3.pt --nosave --cache
# %cd yolov3
# python train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights '' --cfg yolov3.yaml --nosave --cache
# %cd yolov3
# python train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights yolov3-tiny.pt --nosave --cache
# %cd yolov3
# python train.py --img 640 --batch 16 --epochs 3 --data /content/coco128/coco128.yaml --weights /content/coco128/yolov3-tiny.pt --nosave --cache
# %cd yolov3
# python train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights yolov3-spp.pt --nosave --cache
# Out:
# [WinError 2] 지정된 파일을 찾을 수 없습니다: '../yolov3;'
# c:\Users\LegendKi\Documents\LegendKi_py\Deeplearning_CV\yolov3
# wandb: WARNING  wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# train: weights=yolov3.pt, cfg=, data=coco128.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# ...

# %% [markdown]
# ### COCO128 데이터 디렉토리를 변경후 학습 수행
# * /data 아래에 coco128 데이터 download 후 unzip
# * coco128 디렉토리가 변경되었으므로 coco128.yaml 데이터도 변경 적용.

# %%
# Deeplearning_CV 디렉토리에 coco128.zip을 download하고 tmp.zip으로 이름 변경 후 압축 해제. 
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ./ && rm tmp.zip

# %%
# /data 디렉토리에 coco128.zip을 download하고 압축 해제
# !wget -O data/coco128.zip https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip
# !unzip data/coco128.zip

# %%
# !wget -O data/coco128/coco128_renew.yaml https://raw.githubusercontent.com/chulminkw/DLCV/master/data/util/coco128_renew.yaml
# !cat data/coco128/coco128_renew.yaml
# Out:
# data/coco128/coco128_renew.yaml: No such file or directory
# 'cat'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# %cd ../yolov3
# !python train.py --img 640 --batch 16 --epochs 3 --data ../data/coco128/coco128_renew.yaml --weights yolov3.pt --nosave --cache
# Out:
# c:\Users\LegendKi\Documents\LegendKi_py\Deeplearning_CV\yolov3
# wandb: WARNING  wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# train: weights=yolov3.pt, cfg=, data=../data/coco128/coco128_renew.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github:  YOLOv3 is out of date by 2768 commits. Use 'git pull ultralytics master' or 'git clone https://github.com/ultralytics/yolov5' to update.
# ...
